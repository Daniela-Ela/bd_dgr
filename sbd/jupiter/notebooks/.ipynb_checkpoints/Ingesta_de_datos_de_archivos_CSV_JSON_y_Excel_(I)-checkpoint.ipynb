# %% [markdown]
# # **PR0301: Lectura de datos de archivos**

# %% [markdown]
# ## **Objetivo de la Práctica**

# %% [markdown]
# Supón que trabajas para una empresa que acaba de fusionar sus operaciones de tres regiones distintas (Norte, Sur y Este). El problema es que cada región gestionaba sus datos de ventas con sistemas diferentes y necesitas un **Dataset Maestro** unificado para el Dashboard de BI.
#
# Las fuentes de datos son:
# 1. **Región Norte (ventas_norte.csv)**: un sistema legado que exporta archivos de texto separados por punto y coma (**``;``**).
# 2. **Región Sur (ventas_sur.xlsx)**: el equipo de ventas usa Excel. El archivo contiene **múltiples pestañas** (una por mes).
# 3. **Región Este (ventas_este.json)**: eatos provenientes de una API moderna. La información del producto y del cliente está **anidada** dentro de diccionarios.

# %% [markdown]
# ### **Las cosas que tienes que tener en cuenta son:**

# %% [markdown]
# 1. **Ingesta CSV**: cargar los datos del Norte correctamente.

# %%
import pandas as pd

df_norte = pd.read_csv("./ventas_norte.csv", sep=";", parse_dates=["Fecha_Venta"])
print(df_norte.head())
# Out:
#    ID_Transaccion Fecha_Venta Nom_Producto  Cantidad_Vendida  Precio_Unit
# 0            1000  2023-02-21       Laptop                 4          423
# 1            1001  2023-01-15       Laptop                 2          171
# 2            1002  2023-03-13       Laptop                 3           73
# 3            1003  2023-03-02      Teclado                 1          139
# 4            1004  2023-01-21      Monitor                 4          692

# %% [markdown]
# 2. **Ingesta Excel**: leer todas las pestañas del archivo Excel del Sur y combinarlas en un solo DataFrame.

# %%
# !pip install openpyxl
# !pip install xlrd
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: xlrd in /opt/conda/lib/python3.11/site-packages (2.0.1)

# %%
df_sur_dict = pd.read_excel("./ventas_sur.xlsx", sheet_name=None,engine="openpyxl", header=0 , usecols='A:E', names = {'id', 'fecha', 'producto', 'cantidad', 'precio' }, parse_dates=['date'], dtype={'producto'})

df_sur = pd.concat(df_sur_dict.values(), ignore_index=True)

df_sur
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_sur_dict = pd.read_excel("./ventas_sur.xlsx",sheet_name=None,engine="openpyxl", header=0 , usecols='A:E', names = {'id', 'fecha', 'producto', 'cantidad', 'precio' }, parse_dates=['date'], dtype={'producto'})
#       3 df_sur = pd.concat(df_sur_dict.values(), ignore_index=True)
#       5 df_sur
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/excel/_base.py:517, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#     516 try:
# --> 517     data = io.parse(
#     518         sheet_name=sheet_name,
#     519         header=header,
#     520         names=names,
#     521         index_col=index_col,
#     522         usecols=usecols,
#     523         dtype=dtype,
#     524         converters=converters,
#     525         true_values=true_values,
#     526         false_values=false_values,
#     527         skiprows=skiprows,
#     528         nrows=nrows,
#     529         na_values=na_values,
#     530         keep_default_na=keep_default_na,
#     531         na_filter=na_filter,
#     532         verbose=verbose,
#     533         parse_dates=parse_dates,
#     534         date_parser=date_parser,
#     535         date_format=date_format,
#     536         thousands=thousands,
#     537         decimal=decimal,
#     538         comment=comment,
#     539         skipfooter=skipfooter,
#     540         dtype_backend=dtype_backend,
#     541     )
#     542 finally:
#     543     # make sure to close opened file handles
#     544     if should_close:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/excel/_base.py:1629, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1589 def parse(
#    1590     self,
#    1591     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1609     **kwds,
#    1610 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1611     """
#    1612     Parse specified sheet(s) into a DataFrame.
#    1613
#    (...)
#    1627     >>> file.parse()  # doctest: +SKIP
#    1628     """
# -> 1629     return self._reader.parse(
#    1630         sheet_name=sheet_name,
#    1631         header=header,
#    1632         names=names,
#    1633         index_col=index_col,
#    1634         usecols=usecols,
#    1635         converters=converters,
#    1636         true_values=true_values,
#    1637         false_values=false_values,
#    1638         skiprows=skiprows,
#    1639         nrows=nrows,
#    1640         na_values=na_values,
#    1641         parse_dates=parse_dates,
#    1642         date_parser=date_parser,
#    1643         date_format=date_format,
#    1644         thousands=thousands,
#    1645         comment=comment,
#    1646         skipfooter=skipfooter,
#    1647         dtype_backend=dtype_backend,
#    1648         **kwds,
#    1649     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/excel/_base.py:931, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     929     except Exception as err:
#     930         err.args = (f"{err.args[0]} (sheet: {asheetname})", *err.args[1:])
# --> 931         raise err
#     933 if last_sheetname is None:
#     934     raise ValueError("Sheet name is an empty list")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/excel/_base.py:893, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     891 # GH 12292 : error when read one empty column from excel file
#     892 try:
# --> 893     parser = TextParser(
#     894         data,
#     895         names=names,
#     896         header=header,
#     897         index_col=index_col,
#     898         has_index_names=has_index_names,
#     899         dtype=dtype,
#     900         true_values=true_values,
#     901         false_values=false_values,
#     902         skiprows=skiprows,
#     903         nrows=nrows,
#     904         na_values=na_values,
#     905         skip_blank_lines=False,  # GH 39808
#     906         parse_dates=parse_dates,
#     907         date_parser=date_parser,
#     908         date_format=date_format,
#     909         thousands=thousands,
#     910         decimal=decimal,
#     911         comment=comment,
#     912         skipfooter=skipfooter,
#     913         usecols=usecols,
#     914         dtype_backend=dtype_backend,
#     915         **kwds,
#     916     )
#     918     output[asheetname] = parser.read(nrows=nrows)
#     920     if header_names:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1847, in TextParser(*args, **kwds)
#    1792 """
#    1793 Converts lists of lists/tuples into DataFrames with proper type inference
#    1794 and optional (e.g. string to datetime) conversion. Also enables iterating
#    (...)
#    1844     .. versionchanged:: 1.2
#    1845 """
#    1846 kwds["engine"] = "python"
# -> 1847 return TextFileReader(*args, **kwds)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/python_parser.py:161, in PythonParser.__init__(self, f, **kwds)
#     158 if self._col_indices is None:
#     159     self._col_indices = list(range(len(self.columns)))
# --> 161 self._parse_date_cols = self._validate_parse_dates_presence(self.columns)
#     162 self._no_thousands_columns = self._set_no_thousand_columns()
#     164 if len(self.decimal) != 1:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/parsers/base_parser.py:242, in ParserBase._validate_parse_dates_presence(self, columns)
#     232 missing_cols = ", ".join(
#     233     sorted(
#     234         {
#    (...)
#     239     )
#     240 )
#     241 if missing_cols:
# --> 242     raise ValueError(
#     243         f"Missing column provided to 'parse_dates': '{missing_cols}'"
#     244     )
#     245 # Convert positions to actual column names
#     246 return [
#     247     col if (isinstance(col, str) or col in columns) else columns[col]
#     248     for col in cols_needed
#     249 ]
#
# ValueError: Missing column provided to 'parse_dates': 'date' (sheet: Enero)

# %% [markdown]
# 3. **Ingesta JSON (Semi-estructurado)**: cargar los datos del Este. Deberás usar **``pd.json_normalize``** para aplanar la información anidada (desglosar el diccionario de productos en columnas individuales).

# %% [markdown]
# 4. **Transformación y Limpieza**:
# - Asegúrate de que las columnas tengan nombres estándar en los tres DataFrames (ej: ``fecha``, ``producto``, ``cantidad``, ``precio_unitario``, ``region``). Esto puedes hacerlo con la función **``rename()``** de Pandas.
# - Crea una columna nueva llamada region que indique de dónde viene cada fila (“Norte”, “Sur”, “Este”).

# %% [markdown]
# 5. **Consolidación**: concatena los tres DataFrames en uno solo (``df_total``). Recuerda que puedes concatenar varios dataframes de Pandas con la función **``concat()``**

# %% [markdown]
# **Exportación Estandarizada**: guarda el resultado final en un archivo **CSV** llamado ``ventas_consolidadas.csv``. Para ello tienes la función **``to_csv()``** de Pandas. El archivo resultante debe usar coma (``,``) como separador, codificación ``utf-8`` y **no debe incluir el índice** numérico del DataFrame (parámetro ``index=False``).
