# %% [markdown]
# # Introducción a Redis

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
# !pip install redis
# Out:
# Collecting redis
#   Downloading redis-6.4.0-py3-none-any.whl.metadata (10 kB)
# Downloading redis-6.4.0-py3-none-any.whl (279 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.8/279.8 kB 1.1 MB/s eta 0:00:00a 0:00:01m
# Installing collected packages: redis
# Successfully installed redis-6.4.0

# %%
import redis
r = redis.Redis(
    host='redis',
    port=6379,
    db=0,
    decode_responses=True
)

# %%
r.ping()
# Out:
# True

# %%
r.set("ciclo", "Especialización IA y Big Data")
# Out:
# True

# %%
print( r.get("ciclo") )
# Out:
# Especialización IA y Big Data

# %%
r.set("curso", "primero", ex=10)
# Out:
# True
